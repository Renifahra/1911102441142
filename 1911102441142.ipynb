# %% [markdown]
# Nama : Reni Fahra
#
# Nim  : 1911102441142

# %%
# upload file yang sudah diunduh
# file akan disimpan sesuai dengan nama file yang diunggah
from google.colab import files
# memanggil library opencv
import cv2
#menampilkan gambar
file = files.upload()
# Out:
#      <input type="file" id="files-428b74ed-cd45-471e-ad4c-c93c5d3e07ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-428b74ed-cd45-471e-ad4c-c93c5d3e07ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving UMKT.jpeg to UMKT.jpeg

# %%
# !ls
# memanggil fungsi google colab untuk perbaikan cv2.imshow
from google.colab.patches import cv2_imshow
# menyimpan gambar dengan fungsi imread dari OpenCV
# sesuaikan dengan nama file yang diunggah pada cell sebelumnya
img = cv2.imread('UMKT.jpeg')
# menampilkan gambar dengan fungsi cv2_imshow
cv2_imshow(img)
# Out:
# sample_data  UMKT.jpeg
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FB8B6D59910>

# %%
from matplotlib import pyplot as plt
# membuat sebuah variabel kosong 'fig'
fig = plt.figure()
fig.add_subplot(121)
# subplot (jumlah baris, jumlah kolom, urutan)
# menampilkan gambar dengan fungsi plt
plt.imshow(img)
# plotting gambar
fig.add_subplot(122)
# subplot, formatnya: (jumlah baris, jumlah kolom, urutan)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

plt.show()#untuk menampilkan plot

# %%
img = cv2.imread("UMKT.jpeg")[:, :, ::-1]
fig, axes = plt.subplots(2, 2, figsize = (8, 8))

fig.tight_layout()

axes = axes.ravel()
axes[0].imshow(img)
axes[1].imshow(img[:, ::-1, :])
axes[2].imshow(img[::-1, :, :])
axes[3].imshow(img[::-1, ::-1, :])
